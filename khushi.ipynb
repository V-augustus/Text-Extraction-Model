# %%
import cv2
import numpy as np

img_cv = cv2.imread('hinditest.jpg', cv2.IMREAD_GRAYSCALE)
_, img_thresh = cv2.threshold(img_cv, 150, 255, cv2.THRESH_BINARY)
text = pytesseract.image_to_string(img_thresh, lang='hin')
print(text)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 6
#       4 img_cv = cv2.imread('hinditest.jpg', cv2.IMREAD_GRAYSCALE)
#       5 _, img_thresh = cv2.threshold(img_cv, 150, 255, cv2.THRESH_BINARY)
# ----> 6 text = pytesseract.image_to_string(img_thresh, lang='hin')
#       7 print(text)
#
# NameError: name 'pytesseract' is not defined

# %%
import sys, numpy as np
print(sys.executable)
print(np.__version__)
# Out:
# c:\Users\katiy\Anaconda3\AnacondaLoda\envs\text_extraction\python.exe
# 2.2.6

# %%
import pytesseract

# Set path to your Tesseract executable
pytesseract.pytesseract.tesseract_cmd = r"C:\Program Files\Tesseract-OCR\tesseract.exe"
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 import pytesseract
#       3 # Set path to your Tesseract executable
#       4 pytesseract.pytesseract.tesseract_cmd = r"C:\Program Files\Tesseract-OCR\tesseract.exe"
#
# ModuleNotFoundError: No module named 'pytesseract'

# %%
# !pip install pytesseract
# Out:
# ...
#   Using cached pytesseract-0.3.13-py3-none-any.whl.metadata (11 kB)
# ...
# Using cached pytesseract-0.3.13-py3-none-any.whl (14 kB)
# ...

# %%
import pytesseract
print("pytesseract is installed successfully!")
# Out:
# A module that was compiled using NumPy 1.x cannot be run in
# NumPy 2.2.6 as it may crash. To support both 1.x and 2.x
# versions of NumPy, modules must be compiled with NumPy 2.0.
# Some module may need to rebuild instead e.g. with 'pybind11>=2.12'.
#
# If you are a user of the module, the easiest solution will be to
# downgrade to 'numpy<2' or try to upgrade the affected module.
# We expect that some modules will need time to support NumPy 2.
#
# Traceback (most recent call last):  File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "c:\Users\katiy\Anaconda3\AnacondaLoda\Lib\site-packages\ipykernel_launcher.py", line 18, in <module>
#     app.launch_new_instance()
#   File "c:\Users\katiy\Anaconda3\AnacondaLoda\Lib\site-packages\traitlets\config\application.py", line 1075, in launch_instance
#     app.start()
#   File "c:\Users\katiy\Anaconda3\AnacondaLoda\Lib\site-packages\ipykernel\kernelapp.py", line 739, in start
# ...

# %%
import numpy as np
print("NumPy version:", np.__version__)
# Out:
# NumPy version: 2.2.6

# %%
import numpy as np
print(np.__version__)
# Out:
# 2.2.6

# %%
import numpy as np
import cv2
import pytesseract

print("NumPy:", np.__version__)
print("OpenCV:", cv2.__version__)
print("pytesseract:", pytesseract.get_tesseract_version())
# Out:
# A module that was compiled using NumPy 1.x cannot be run in
# NumPy 2.2.6 as it may crash. To support both 1.x and 2.x
# versions of NumPy, modules must be compiled with NumPy 2.0.
# Some module may need to rebuild instead e.g. with 'pybind11>=2.12'.
#
# If you are a user of the module, the easiest solution will be to
# downgrade to 'numpy<2' or try to upgrade the affected module.
# We expect that some modules will need time to support NumPy 2.
#
# Traceback (most recent call last):  File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "c:\Users\katiy\Anaconda3\AnacondaLoda\Lib\site-packages\ipykernel_launcher.py", line 18, in <module>
#     app.launch_new_instance()
#   File "c:\Users\katiy\Anaconda3\AnacondaLoda\Lib\site-packages\traitlets\config\application.py", line 1075, in launch_instance
#     app.start()
#   File "c:\Users\katiy\Anaconda3\AnacondaLoda\Lib\site-packages\ipykernel\kernelapp.py", line 739, in start
# ...

# %%
import sys
import numpy as np

print(sys.executable)
print(np.__version__)
# Out:
# c:\Users\katiy\Anaconda3\AnacondaLoda\python.exe
# 2.2.6

# %%
import sys
import numpy as np

print(sys.executable)
print(np.__version__)
# Out:
# c:\Users\katiy\Anaconda3\AnacondaLoda\envs\text_extraction\python.exe
# 2.2.6
