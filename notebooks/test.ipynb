# %%
from src.preprocessing import preprocess_image
from src.detection import detect_text_regions
import cv2, matplotlib.pyplot as plt

img_path = "images/image1.png"
pre = preprocess_image(img_path)
boxes = detect_text_regions(pre)

img = cv2.imread(img_path)
for (x,y,w,h) in boxes:
    cv2.rectangle(img,(x,y),(x+w,y+h),(0,255,0),2)
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB)); plt.axis('off')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 from src.preprocessing import preprocess_image
#       2 from src.detection import detect_text_regions
#       3 import cv2, matplotlib.pyplot as plt
#
# ModuleNotFoundError: No module named 'src'
