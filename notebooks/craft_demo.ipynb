# %%
from craft_text_detector import Craft

craft = Craft(output_dir='./craft_output/', crop_type="poly", cuda=False)

# detect text boxes and get output images
prediction_result = craft.detect_text("../images/image1.png")

# visualize boxes
plt.imshow(prediction_result["text_box_threshold"])
plt.show()

craft.unload_craftnet_model()
craft.unload_refinenet_model()
